# %%
from PIL import Image
import numpy as np
import pandas as pd
from sklearn import decomposition
from sklearn.svm import SVC
from pylab import * 
from sklearn.cross_validation import train_test_split
from os import listdir
from os.path import isfile, join

DIMENSION = 32
ROOT_DIR = "C:/Users/Dameria Desi/Documents/TA/IMAGE/images/best_seller"
BEST = "best_seller"
NBEST = "non_best_seller"
CLASSES = [BEST, NBEST]

# def getData(generateTuningData):
#     trainingData = {}
#     tuneData = {}
#     testData = {}

#     for clazz in CLASSES:
#         (train, tune, test) = buildTrainTestVectors(buildImageList(ROOT_DIR + clazz + "/"), generateTuningData)
#         trainingData[clazz] = train
#         tuneData[clazz] = tune
#         testData[clazz] = test

#     return (trainingData, tuneData, testData)

# def buildImageList(dirName):
#     imgs = [Image.open(dirName + fileName).resize((DIMENSION, DIMENSION)) for fileName in os.listdir(dirName)]
#     imgs = [list(itertools.chain.from_iterable(img.getdata())) for img in imgs]
#     return imgs

onlyfiles = [f for f in listdir(ROOT_DIR) if isfile(join(ROOT_DIR, f))]

for i in onlyfiles:
 Image.open(join(ROOT_DIR,i))
a = Image.open(join(ROOT_DIR,i))   
immatrix = array([array(a).flatten()
                  for i in onlyfiles],"f")
print immatrix  

pca = decomposition.PCA(n_components=10)
pca.fit(immatrix)
imatrix = pca.fit(immatrix)
print imatrix



# for k in onlyfiles: 
    

# pca.fit(immatrix)


# print immatr
# for w in movie_reviews.words():
#     all_words.append(w.lower())
    
# Image.open(join(ROOT_DIR,onlyfiles[1]))

#  x = np.array([np.array(Image.open(fname)) for fname in imlist])
# a = buildImageList


# #out = im.resize((128,128))  #preprosssing

# print immatrix
# pca = decomposition.PCA(n_components=10) # dimensional reduction PCA

# imatrix = pca.transform(immatrix)
   
# print imatrix
# kategori_list = ['yes', 'no', 'yes', 'no', 'yes', 'yes', 'yes' ,'yes', 'yes','no'] #set label 


# imatrix= np.array(imatrix)

# data = pd.DataFrame([list(imatrix),list(kategori_list)])
# data = data.T
# Out:
# [[ 118.  109.  102. ...,  135.  156.  161.]
#  [ 118.  109.  102. ...,  135.  156.  161.]
#  [ 118.  109.  102. ...,  135.  156.  161.]
#  ...,
#  [ 118.  109.  102. ...,  135.  156.  161.]
#  [ 118.  109.  102. ...,  135.  156.  161.]
#  [ 118.  109.  102. ...,  135.  156.  161.]]
# PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
X = data.iloc[:,:-1]
X.head()
# Out:
#                                                    0
# 0  [30425.5152502, 15168.1465111, -7585.24700537,...
# 1  [15710.5399856, -12612.7479672, 10517.8229066,...
# 2  [-8314.683738, 1178.84853968, -5414.16216508, ...
# 3  [2926.72221093, -5660.62963017, 2104.59702847,...
# 4  [836.569854236, -5083.33577342, 3383.30966284,...

# %%
list_img = []
for i in range (len(X[0])):
    list_img.append([value for value in X[0][i]])

for l in list_img:
    print l
print list_img
# Out:
# [30425.515250240329, 15168.146511083991, -7585.2470053738571, 1916.8653992932154, 1023.043298812522, -684.50962210690057, -1373.1383072953192, -284.80334026871736, 0.69032431114677528, 1.4846510132393576e-10]
# [15710.539985591156, -12612.747967169345, 10517.822906594476, 7171.2677257595496, -1039.6834148770836, 3628.381674324256, 3205.5051170316979, 1791.3613471966112, -4158.1470920968313, 7.4115311110567461e-11]
062.9021516323985, -5704.886038866809, 1990.0877581843113, -2496.5692057687297, -1.2678617183903285e-10], [-8659.6882812059703, 3717.7189339598572, -5337.1899557506276, -3906.0009836258264, -4308.6737123403464, 12017.325809509943, 2447.403899874676, 2355.6426594257264, 1767.3055460824223, -6.5148910571855012e-11], [-766.59467708556656, -10912.12505390196, -5745.0135595791016, -2679.2534626974152, 12442.183002160491, 2175.3936931210137, -1585.5499097116331, -3462.6133119501001, 1121.4129517453632, -4.6988725410646026e-11]]

# %%
from sklearn.preprocessing import LabelEncoder
y = data.iloc[:,-1]


category_encoder = LabelEncoder()
y = category_encoder.fit_transform(y)
y
# Out:
# array([1, 0, 1, 0, 1, 1, 1, 1, 1, 0], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(list_img, y, test_size=0.2, random_state=1)

# %%
X_train
# Out:
# [[-2183.3305844960246,
#   -4458.9302247557944,
#   -3877.4777551891725,
#   -5553.0067957298115,
#   -7080.8675879871307,
#   -2593.1426855420236,
#   -1659.1305490368434,
#   -7781.3852731551669,
#   -5907.7608803966468,
#   5.3891970747121931e-11],
#  [836.56985423583478,
#   -5083.3357734220053,
#   3383.3096628381022,
#   3584.6348487391901,
#   -4870.8443815606297,
#   -2544.2759323770538,
#   -969.17441785879782,
#   -3924.5662886575415,
#   9968.2066373259931,
#   4.5876434595637505e-11],
#  [30425.515250240329,
#   15168.146511083991,
#   -7585.2470053738571,
#   1916.8653992932154,
#   1023.043298812522,
#   -684.50962210690057,
#   -1373.1383072953192,
#   -284.80334026871736,
#   0.69032431114677528,
#   1.4846510132393576e-10],
#  [2926.7222109335271,
#   -5660.629630168216,
#   2104.5970284677969,
#   -7863.571529612469,
#   -1409.1239498286031,
#   -4203.3299136648211,
#   -5713.4328229232988,
#   9091.5345476087932,
#   439.70112009257076,
#   2.4674262633084254e-11],
#  [15710.539985591156,
#   -12612.747967169345,
#   10517.822906594476,
#   7171.2677257595496,
#   -1039.6834148770836,
#   3628.381674324256,
#   3205.5051170316979,
#   1791.3613471966112,
#   -4158.1470920968313,
#   7.4115311110567461e-11],
#  [-20990.73270324144,
#   4244.0299446761037,
#   -4984.1564068435782,
#   11076.838305939636,
#   284.45498955082371,
#   -1062.9021516323985,
#   -5704.886038866809,
#   1990.0877581843113,
#   -2496.5692057687297,
#   -1.2678617183903285e-10],
#  [-8659.6882812059703,
#   3717.7189339598572,
#   -5337.1899557506276,
#   -3906.0009836258264,
#   -4308.6737123403464,
#   12017.325809509943,
#   2447.403899874676,
#   2355.6426594257264,
#   1767.3055460824223,
#   -6.5148910571855012e-11],
#  [-8984.3173169736638,
#   14419.024720015865,
#   16937.517249917819,
#   -3548.6345940798797,
#   3911.9305523102221,
#   -47.862263129740818,
#   77.071666372066318,
#   -2380.770424074316,
#   -642.68535201942893,
#   2.23910542884731e-11]]

# %%
y_train
# Out:
# array([1, 1, 1, 0, 0, 1, 1, 1], dtype=int64)

# %%
from sklearn.svm import SVC
from sklearn import metrics
svc = SVC()
svc.fit(X_train,y_train)
y_pred = svc.predict(X_test)
print('Accuracy scoreL')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy scoreL
# 0.5

# %%
# X_train
# X_train[0][0]
# X_train[0][2]
# X_train[0][2]
# X_train[0][3]
# X_train[0][4]
# X_train[0][5]
# X_train[0][6]
# X_train[0][7]
